# %%
from datasets import load_dataset

ds = load_dataset("adesouza1/soap_notes")

# %%
ds
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['age', 'patient_name', 'doctor_data', 'gender', 'dob', 'phone', 'person_data', 'health_problem', 'patient_convo', 'soap_notes', 'doctor_name', 'address', 'full_patient_data'],
#         num_rows: 558
#     })
#     test: Dataset({
#         features: ['age', 'patient_name', 'doctor_data', 'gender', 'dob', 'phone', 'person_data', 'health_problem', 'patient_convo', 'soap_notes', 'doctor_name', 'address', 'full_patient_data'],
#         num_rows: 62
#     })
# })

# %%
ds['train'][0].keys()
# Out:
# dict_keys(['age', 'patient_name', 'doctor_data', 'gender', 'dob', 'phone', 'person_data', 'health_problem', 'patient_convo', 'soap_notes', 'doctor_name', 'address', 'full_patient_data'])

# %%
ds['train'][0]['health_problem']
# Out:
# 'Joint Pain'

# %%
ds['train'][0]['full_patient_data']
# Out:
# '\n\n\nDEMOGRAPHICS:\nName: Zack Fields\nAge: 28\nAddress: 6104 Parker Rd, Minneapolis, Georgia 60074\nPhone: (839) 255-2098\n\nPROBLEM LIST:\n1. Chronic: Joint Pain (Right Knee and Left Ankle)\n2. Other: Seasonal Allergies\n\nHEALTH MAINTENANCE:\nVaccines and Screenings:\n- Tdap: 08/14/2022 (overdue)\n- Influenza: 10/02/2022 (due soon)\n- Colonoscopy: 09/15/2023 (not due yet)\n\nREMINDERS AND RESULTS:\n- Reminder: Tdap booster due\n- Reminder: Schedule annual physical\n- Result: Lipid Panel (09/15/2022): Normal\n\nCARE TEAM AND COMMUNICATION:\nCare Team:\n- Dr. Kristen Kelly, Primary Care Physician\n- Dr. Rebecca Nguyen, Orthopedic Surgeon\n- Sarah Johnson, Nurse Practitioner\n- John Smith, Physical Therapist\n\nCommunication:\n- Preferred Method: Email\n- Emergency Contact: Jane Fields, Mother, (555) 123-4567\n\nALLERGIES:\n- Penicillin\n\nMEDICATIONS:\n- Ibuprofen 600mg, PRN, every 4-6 hours as needed for pain\n- Loratadine 10mg, daily for allergies\n\nIMMUNIZATIONS:\n- Tdap: 08/14/2022\n- Influenza: 10/02/2022\n- Hepatitis B: 03/15/1996\n- Measles, Mumps, Rubella: 04/12/1996\n- Varicella: 05/23/1996\n\nSIGNIFICANT HISTORY DETAILS:\n- Tobacco Use: Never\n- Alcohol Use: Occasional\n- Language they speak: English\n\nSPECIALTY COMMENTS:\n- Dr. Nguyen: "Mr. Fields has been experiencing joint pain in his right knee and left ankle for the past 6 months. MRI results show mild to moderate arthritis. I recommend physical therapy and a trial of NSAIDs."\n\nFAMILY COMMENTS:\n- Jane Fields (Mother): "Zack has been having a hard time with the pain. He\'s been avoiding physical activities. I\'m worried about his mental health."'

# %%
ds['train'][0]['patient_convo']
# Out:
# "\nPhysician: Good morning, Zack. How are you feeling today?\n\nPatient: Hi, Doc. I've been feeling pretty lousy lately. I've got this constant pain in my right knee and left ankle that just won't go away. It's like a dull ache that's always there, no matter what I'm doing.\n\nPhysician: I see. Can you tell me more about the pain? Is it sharp, dull, throbbing? Does it feel like it's affecting your ability to move around?\n\nPatient: It's definitely dull and achy. It's not excruciating, but it's definitely noticeable. It's like there's pressure on my joints all the time. Yeah, it's definitely affecting my mobility. I've been avoiding stairs and stuff because it just hurts too much.\n\nPhysician: Okay, that helps. Have you noticed any swelling or redness in the affected areas?\n\nPatient: Not really. I mean, sometimes my knee will get a little puffy if I've been walking or standing for a while, but it's not like it's massively swollen or anything.\n\nPhysician: Got it. And how long have you been experiencing this pain?\n\nPatient: It started about six months ago. At first, it was just a little twinge every now and then, but it's gradually gotten worse over time.\n\nPhysician: I understand. Have you noticed any triggers that make the pain better or worse?\n\nPatient: Well, like I said, it gets worse when I'm walking or standing for a long time. But it also seems to get better if I'm sitting or lying down for a bit.\n\nPhysician: Okay, that's helpful. And have you tried any treatments or medications so far to help manage the pain?\n\nPatient: Yeah, I've been taking ibuprofen pretty regularly, but it only seems to help a little bit. And sometimes it makes my stomach feel weird, so I don't want to take too much of it.\n\nPhysician: I see. Well, based on what you've told me, it sounds like we're looking at a possible diagnosis of osteoarthritis. We'll need to do some further testing to confirm that, but in the meantime, I think we can start by prescribing you a different medication that might be more effective at managing your pain. I'd also like to refer you to physical therapy to help improve your mobility and reduce the strain on your joints. Does that sound good to you?\n\nPatient: Yeah, that sounds like a plan. Thanks, Doc.\n\nPhysician: You're welcome, Zack. We'll get you set up with a physical therapist and get that medication prescription sent over to your pharmacy. In the meantime, try to avoid any heavy lifting or bending, and see if you can take it easy on your joints for a bit. We'll follow up in a few weeks to see how you're doing and reassess from there. Sound good?\n\nPatient: Sounds good to me. Thanks again."

# %%
ds['train'][0]['soap_notes']
# Out:
# "Subjective:\nZack Fields reports experiencing constant pain in his right knee and left ankle for the past six months. He describes the pain as a dull ache that is always present and affects his mobility, particularly when walking or standing for extended periods. He notes that the pain improves when he is sitting or lying down. Zack has been taking ibuprofen for pain relief, but it provides only minimal relief and occasionally causes stomach discomfort.\n\nObjective:\nDuring the examination, Zack appeared uncomfortable when moving his right knee and left ankle. There were no signs of swelling or redness in the affected joints. Zack's range of motion in both joints was limited due to pain. He is currently taking ibuprofen 600mg as needed for pain relief. Zack's mother expressed concerns about his mental health due to the impact of the pain on his daily activities.\n\nAssessment:\nBased on Zack's symptoms and history, the likely diagnosis is osteoarthritis in the right knee and left ankle. Further testing is needed to confirm the diagnosis. Zack's current pain management with ibuprofen is suboptimal, and he experiences occasional gastrointestinal side effects. Referral to physical therapy is recommended to improve mobility and reduce strain on the affected joints.\n\nPlan:\n1. Prescribe a different medication for pain management that may be more effective and have fewer gastrointestinal side effects.\n2. Refer Zack to physical therapy to address mobility issues and strengthen the affected joints.\n3. Advise Zack to avoid heavy lifting or bending and to take it easy on his joints.\n4. Follow up with Zack in a few weeks to assess his progress and adjust the treatment plan as needed."

# %%
# src/data_loader.py

from datasets import load_dataset
from typing import Dict, List

class SOAPDataLoader:
    def __init__(self, dataset_name: str = "adesouza1/soap_notes"):
        self.dataset = load_dataset(dataset_name)
    
    def get_examples(self, split: str = "train", n: int = None):
        """Get n examples from dataset"""
        data = self.dataset[split]
        if n:
            data = data.select(range(min(n, len(data))))
        
        return [
            {
                'patient_convo': ex['patient_convo'],
                'soap_notes': ex['soap_notes'],
                'full_patient_data': ex['full_patient_data'],
                'health_problem': ex['health_problem']
            }
            for ex in data
        ]

# %%
# src/evals/structure_eval.py

import re

class StructureEvaluator:
    """Check if SOAP note has all required sections"""
    
    REQUIRED_SECTIONS = ['Subjective', 'Objective', 'Assessment', 'Plan']
    
    def evaluate(self, generated_note: str) -> dict:
        results = {
            'has_all_sections': True,
            'missing_sections': [],
            'section_lengths': {}
        }
        
        for section in self.REQUIRED_SECTIONS:
            # Check if section exists
            pattern = rf'{section}:?\s*\n'
            if not re.search(pattern, generated_note, re.IGNORECASE):
                results['has_all_sections'] = False
                results['missing_sections'].append(section)
            else:
                # Measure section length
                section_text = self._extract_section(generated_note, section)
                results['section_lengths'][section] = len(section_text.split())
        
        return results
    
    def _extract_section(self, note: str, section: str) -> str:
        """Extract text from a specific section"""
        # Simple regex to get section content
        pattern = rf'{section}:?\s*\n(.*?)(?=\n[A-Z][a-z]+:|\Z)'
        match = re.search(pattern, note, re.IGNORECASE | re.DOTALL)
        return match.group(1).strip() if match else ""

# %%
# Load data
loader = SOAPDataLoader()
examples = loader.get_examples(n=10)  # Start with 10

# Run eval
evaluator = StructureEvaluator()

for i, example in enumerate(examples):
    result = evaluator.evaluate(example['soap_notes'])
    print(f"\n--- Example {i} ---")
    print(f"All sections present: {result['has_all_sections']}")
    if result['missing_sections']:
        print(f"Missing: {result['missing_sections']}")
    print(f"Section lengths: {result['section_lengths']}")
# Out:
# --- Example 0 ---
# All sections present: True
# Section lengths: {'Subjective': 74, 'Objective': 68, 'Assessment': 57, 'Plan': 71}
#
# --- Example 1 ---
# All sections present: True
# Section lengths: {'Subjective': 44, 'Objective': 42, 'Assessment': 34, 'Plan': 32}
#
# --- Example 2 ---
# All sections present: True
# Section lengths: {'Subjective': 52, 'Objective': 44, 'Assessment': 43, 'Plan': 74}
#
# --- Example 3 ---
# All sections present: True
# Section lengths: {'Subjective': 50, 'Objective': 56, 'Assessment': 57, 'Plan': 42}
#
# --- Example 4 ---
# All sections present: True
# Section lengths: {'Subjective': 79, 'Objective': 47, 'Assessment': 59, 'Plan': 97}
#
# --- Example 5 ---
# All sections present: True
# Section lengths: {'Subjective': 69, 'Objective': 47, 'Assessment': 48, 'Plan': 98}
#
# --- Example 6 ---
# All sections present: True
# Section lengths: {'Subjective': 38, 'Objective': 55, 'Assessment': 51, 'Plan': 57}
#
# --- Example 7 ---
# All sections present: True
# Section lengths: {'Subjective': 57, 'Objective': 56, 'Assessment': 37, 'Plan': 44}
#
# --- Example 8 ---
# All sections present: True
# Section lengths: {'Subjective': 59, 'Objective': 49, 'Assessment': 34, 'Plan': 48}
#
# --- Example 9 ---
# All sections present: True
# Section lengths: {'Subjective': 59, 'Objective': 45, 'Assessment': 52, 'Plan': 66}

# %%
import medspacy

# %%
nlp = medspacy.load()

# %%
example['patient_convo']
# Out:
# "\n\nPhysician: Good morning, Mr. Diaz. How are you feeling today?\n\nPatient: Hi, Dr. Burns. I've been feeling pretty lousy lately. I've had this constant heartburn that doesn't seem to go away, even when I take my medication. And sometimes, I get this sharp pain in my stomach that makes me feel like I'm going to throw up.\n\nPhysician: I see. Have you noticed any other symptoms? Maybe some bloating or abdominal discomfort?\n\nPatient: Yeah, I do get bloated a lot, and sometimes I have this feeling of fullness that lasts for hours. And the abdominal pain can be pretty intense. It's like someone is stabbing me with a knife.\n\nPhysician: I understand. Have you had any changes in your bowel movements? Maybe some diarrhea or constipation?\n\nPatient: Well, I have had some diarrhea lately, but it's not always there. And sometimes, I feel like I can't go to the bathroom even when I need to. It's like my body is just not responding.\n\nPhysician: Okay, that's helpful. Have you noticed any other symptoms? Maybe some nausea or vomiting?\n\nPatient: Yes, I do get nauseous sometimes, especially when I eat certain foods. And I have vomited a few times, but it's not constant.\n\nPhysician: I see. Have you had any recent weight changes or loss of appetite?\n\nPatient: Well, I have lost a little bit of weight recently, but I think that's because I just don't feel like eating much. And sometimes, I get this feeling of being really tired all the time.\n\nPhysician: Okay, that's good to know. Have you noticed any triggers that make your symptoms worse? Maybe certain foods or stress?\n\nPatient: Yeah, I think spicy foods make my heartburn worse, and sometimes, I feel like stress does too. But it's hard to say for sure.\n\nPhysician: That's understandable. Have you had any recent travel or exposures to illness?\n\nPatient: No, nothing recent. I did go on a trip to Mexico a few months ago, but I don't think that's related.\n\nPhysician: Okay, that's good to know. I'm going to order some tests to help us better understand what's going on. We'll do an endoscopy to take a look at your esophagus and stomach, and we'll also do some blood tests to check for any infections or inflammation. In the meantime, I'd like you to start keeping a food diary to track any triggers that might be making your symptoms worse. Does that sound good to you?\n\nPatient: Yes, that sounds like a good plan. Thank you, Dr. Burns.\n\nPhysician: You're welcome, Mr. Diaz. We'll get to the bottom of this and figure out the best course of treatment for you."

# %%
example = examples[1]
# logging.getLogger("PyRuSH").setLevel(logging.WARNING)
transcript = nlp(example['soap_note'])
# Out:
# 2025-11-04 18:03:29.148 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 1 'Physician' marked as sentence start (span begin)
# 2025-11-04 18:03:29.148 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 9 'How' marked as sentence start (span end next token)
# 2025-11-04 18:03:29.149 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 9 'How' marked as sentence start (span begin)
# 2025-11-04 18:03:29.149 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 15 '
#
# ' marked as sentence start (span end whitespace)
# 2025-11-04 18:03:29.150 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] GAP DETECTED: tokens 15-15 (idx 63-63) between spans 63-65
# 2025-11-04 18:03:29.151 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 15 '
#
# ' marked as sentence start (whitespace in gap between spans)
# 2025-11-04 18:03:29.151 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 16 'Patient' marked as sentence start (span begin)
# 2025-11-04 18:03:29.152 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 23 'I' marked as sentence start (span end next token)
# 2025-11-04 18:03:29.153 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 23 'I' marked as sentence start (span begin)
# 2025-11-04 18:03:29.153 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 31 'I' marked as sentence start (span end next token)
# 2025-11-04 18:03:29.154 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 31 'I' marked as sentence start (span begin)
# 2025-11-04 18:03:29.154 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 52 'And' marked as sentence start (span end next token)
# 2025-11-04 18:03:29.155 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 52 'And' marked as sentence start (span begin)
# 2025-11-04 18:03:29.156 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 75 '
#
# ' marked as sentence start (span end whitespace)
# 2025-11-04 18:03:29.156 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] GAP DETECTED: tokens 75-75 (idx 320-320) between spans 320-322
# 2025-11-04 18:03:29.156 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 75 '
#
# ' marked as sentence start (whitespace in gap between spans)
# 2025-11-04 18:03:29.157 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 76 'Physician' marked as sentence start (span begin)
# 2025-11-04 18:03:29.158 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 81 'Have' marked as sentence start (span end next token)
# 2025-11-04 18:03:29.158 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 81 'Have' marked as sentence start (span begin)
# 2025-11-04 18:03:29.159 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 88 'Maybe' marked as sentence start (span end next token)
# 2025-11-04 18:03:29.160 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 88 'Maybe' marked as sentence start (span begin)
# 2025-11-04 18:03:29.160 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 95 '
#
# ' marked as sentence start (span end whitespace)
# 2025-11-04 18:03:29.161 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] GAP DETECTED: tokens 95-95 (idx 421-421) between spans 421-423
# 2025-11-04 18:03:29.161 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 95 '
#
# ' marked as sentence start (whitespace in gap between spans)
# 2025-11-04 18:03:29.162 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 96 'Patient' marked as sentence start (span begin)
# 2025-11-04 18:03:29.162 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 120 'And' marked as sentence start (span end next token)
# 2025-11-04 18:03:29.163 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 120 'And' marked as sentence start (span begin)
# 2025-11-04 18:03:29.163 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 129 'It' marked as sentence start (span end next token)
# 2025-11-04 18:03:29.164 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 129 'It' marked as sentence start (span begin)
# 2025-11-04 18:03:29.165 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 140 '
#
# ' marked as sentence start (span end whitespace)
# 2025-11-04 18:03:29.165 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] GAP DETECTED: tokens 140-140 (idx 622-622) between spans 622-624
# 2025-11-04 18:03:29.165 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 140 '
#
# ' marked as sentence start (whitespace in gap between spans)
# 2025-11-04 18:03:29.166 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 141 'Physician' marked as sentence start (span begin)
# 2025-11-04 18:03:29.166 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 146 'Have' marked as sentence start (span end next token)
# 2025-11-04 18:03:29.166 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 146 'Have' marked as sentence start (span begin)
# 2025-11-04 18:03:29.167 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 156 'Maybe' marked as sentence start (span end next token)
# 2025-11-04 18:03:29.167 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 156 'Maybe' marked as sentence start (span begin)
# 2025-11-04 18:03:29.169 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 162 '
#
# ' marked as sentence start (span end whitespace)
# 2025-11-04 18:03:29.169 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] GAP DETECTED: tokens 162-162 (idx 735-735) between spans 735-737
# 2025-11-04 18:03:29.169 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 162 '
#
# ' marked as sentence start (whitespace in gap between spans)
# 2025-11-04 18:03:29.170 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 163 'Patient' marked as sentence start (span begin)
# 2025-11-04 18:03:29.170 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 181 'And' marked as sentence start (span end next token)
# 2025-11-04 18:03:29.171 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token 181 'And' marked as sentence start (span begin)
# 2025-11-04 18:03:29.171 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=0] [doc 0] Token
| DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=7] [doc 0] Token 2 '
# ' marked as sentence start (whitespace in gap between spans)
# 2025-11-04 16:58:04.040 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=7] [doc 0] Token 3 'Mr.' marked as sentence start (span begin)
# 2025-11-04 16:58:04.041 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=7] [doc 0] Token 17 'He' marked as sentence start (span end next token)
# 2025-11-04 16:58:04.042 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=7] [doc 0] Token 17 'He' marked as sentence start (span begin)
# 2025-11-04 16:58:04.042 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=7] [doc 0] Token 46 'He' marked as sentence start (span end next token)
# 2025-11-04 16:58:04.043 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=7] [doc 0] Token 46 'He' marked as sentence start (span begin)
# 2025-11-04 16:58:04.044 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=7] [doc 0] Token 58 '
#
# ' marked as sentence start (span end whitespace)
# 2025-11-04 16:58:04.045 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=7] [doc 0] GAP DETECTED: tokens 58-58 (idx 330-330) between spans 330-332
# 2025-11-04 16:58:04.045 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=7] [doc 0] Token 58 '
#
# ' marked as sentence start (whitespace in gap between spans)
# 2025-11-04 16:58:04.046 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=7] [doc 0] Token 59 'Objective' marked as sentence start (span begin)
# 2025-11-04 16:58:04.046 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=7] [doc 0] Token 61 '
# ' marked as sentence start (span end whitespace)
# 2025-11-04 16:58:04.046 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=7] [doc 0] GAP DETECTED: tokens 61-61 (idx 342-342) between spans 342-343
# 2025-11-04 16:58:04.047 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=7] [doc 0] Token 61 '
# ' marked as sentence start (whitespace in gap between spans)
# 2025-11-04 16:58:04.047 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=7] [doc 0] Token 62 'Mr.' marked as sentence start (span begin)
# 2025-11-04 16:58:04.048 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=7] [doc 0] Token 70 'He' marked as sentence start (span end next token)
# 2025-11-04 16:58:04.049 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=7] [doc 0] Token 70 'He' marked as sentence start (span begin)
# 2025-11-04 16:58:04.049 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=7] [doc 0] Token 80 'Gastroenterologist' marked as sentence start (span end next token)
# 2025-11-04 16:58:04.049 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=7] [doc 0] Token 80 'Gastroenterologist' marked as sentence start (span begin)
# 2025-11-04 16:58:04.050 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=7] [doc 0] Token 95 'Spouse' marked as sentence start (span end next token)
# 2025-11-04 16:58:04.050 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=7] [doc 0] Token 95 'Spouse' marked as sentence start (span begin)
# 2025-11-04 16:58:04.051 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=7] [doc 0] Token 108 '
#
# ' marked as sentence start (span end whitespace)
# 2025-11-04 16:58:04.051 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=7] [doc 0] GAP DETECTED: tokens 108-108 (idx 639-639) between spans 639-641
# 2025-11-04 16:58:04.051 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=7] [doc 0] Token 108 '
#
# ' marked as sentence start (whitespace in gap between spans)
# 2025-11-04 16:58:04.052 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=7] [doc 0] Token 109 'Assessment' marked as sentence start (span begin)
# 2025-11-04 16:58:04.053 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=7] [doc 0] Token 111 '
# ' marked as sentence start (span end whitespace)
# 2025-11-04 16:58:04.053 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=7] [doc 0] GAP DETECTED: tokens 111-111 (idx 652-652) between spans 652-653
# 2025-11-04 16:58:04.054 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=7] [doc 0] Token 111 '
# ' marked as sentence start (whitespace in gap between spans)
# 2025-11-04 16:58:04.054 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=7] [doc 0] Token 112 'Mr.' marked as sentence start (span begin)
# 2025-11-04 16:58:04.055 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=7] [doc 0] Token 125 'Further' marked as sentence start (span end next token)
# 2025-11-04 16:58:04.055 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=7] [doc 0] Token 125 'Further' marked as sentence start (span begin)
# 2025-11-04 16:58:04.055 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=7] [doc 0] Token 140 'A' marked as sentence start (span end next token)
# 2025-11-04 16:58:04.056 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=7] [doc 0] Token 140 'A' marked as sentence start (span begin)
# 2025-11-04 16:58:04.056 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=7] [doc 0] Token 151 '
#
# ' marked as sentence start (span end whitespace)
# 2025-11-04 16:58:04.056 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=7] [doc 0] GAP DETECTED: tokens 151-151 (idx 887-887) between spans 887-889
# 2025-11-04 16:58:04.057 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=7] [doc 0] Token 151 '
#
# ' marked as sentence start (whitespace in gap between spans)
# 2025-11-04 16:58:04.057 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=7] [doc 0] Token 152 'Plan' marked as sentence start (span begin)
# 2025-11-04 16:58:04.057 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=7] [doc 0] Token 154 '
# ' marked as sentence start (span end whitespace)
# 2025-11-04 16:58:04.059 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=7] [doc 0] GAP DETECTED: tokens 154-154 (idx 894-894) between spans 894-895
# 2025-11-04 16:58:04.059 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=7] [doc 0] Token 154 '
# ' marked as sentence start (whitespace in gap between spans)
# 2025-11-04 16:58:04.060 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=7] [doc 0] Token 155 'Order' marked as sentence start (span begin)
# 2025-11-04 16:58:04.060 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=7] [doc 0] Token 164 'Initiate' marked as sentence start (span end next token)
# 2025-11-04 16:58:04.061 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=7] [doc 0] Token 164 'Initiate' marked as sentence start (span begin)
# 2025-11-04 16:58:04.061 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=7] [doc 0] Token 171 'Follow' marked as sentence start (span end next token)
# 2025-11-04 16:58:04.062 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=7] [doc 0] Token 171 'Follow' marked as sentence start (span begin)
# 2025-11-04 16:58:04.062 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=7] [doc 0] Token 181 'Encourage' marked as sentence start (span end next token)
# 2025-11-04 16:58:04.062 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=7] [doc 0] Token 181 'Encourage' marked as sentence start (span begin)
# 2025-11-04 16:58:04.063 | DEBUG    | PyRuSH.PyRuSHSentencizer:predict:100 - [cpredict_split_gaps|call_id=7] Token/tag mapping: [(Subjective, True), (:, False), (
# , True), (Mr., True), (Diaz, False), (reports, False), (feeling, False), (lousy, False), (lately, False), (with, False), (constant, False), (heartburn, False), (that, False), (persists, False), (despite, False), (medication, False), (., False), (He, True), (also, False), (experiences, False), (sharp, False), (stomach, False), (pain, False), (,, False), (bloating, False), (,, False), (abdominal, False), (discomfort, False), (,, False), (intermittent, False), (diarrhea, False), (,, False), (nausea, False), (,, False), (vomiting, False), (,, False), (weight, False), (loss, False), (,, False), (loss, False), (of, False), (appetite, False), (,, False), (and, False), (fatigue, False), (., False), (He, True), (notes, False), (that, False), (spicy, False), (foods, False), (and, False), (stress, False), (may, False), (exacerbate, False), (his, False), (symptoms, False), (., False), (
#
# , True), (Objective, True), (:, False), (
# , True), (Mr., True), (Diaz, False), (appears, False), (fatigued, False), (during, False), (the, False), (appointment, False), (., False), (He, True), (denies, False), (any, False), (recent, False), (travel, False), (or, False), (exposures, False), (to, False), (illness, False), (., False), (Gastroenterologist, True), (recommends, False), (further, False), (evaluation, False), (with, False), (an, False), (endoscopy, False), (due, False), (to, False), (intermittent, False), (abdominal, False), (pain, False), (and, False), (bloating, False), (., False), (Spouse, True), (notes, False), (fatigue, False), (and, False), (loss, False), (of, False), (appetite, False), (as, False), (additional, False), (symptoms, False), (to, False), (consider, False), (., False), (
#
# , True), (Assessment, True), (:, False), (
# , True), (Mr., True), (Diaz, False), (presents, False), (with, False), (chronic, False), (GERD, False), (,, False), (hypertension, False), (,, False), (and, False), (gastrointestinal, False), (issues, False), (., False), (Further, True), (evaluation, False), (with, False), (an, False), (endoscopy, False), (and, False), (blood, False), (tests, False), (is, False), (warranted, False), (to, False), (investigate, False), (his, False), (symptoms, False), (., False), (A, True), (food, False), (diary, False), (will, False), (be, False), (initiated, False), (to, False), (track, False), (potential, False), (triggers, False), (., False), (
#
# , True), (Plan, True), (:, False), (
# , True), (Order, True), (endoscopy, False), (and, False), (blood, False), (tests, False), (to, False), (investigate, False), (symptoms, False), (., False), (Initiate, True), (food, False), (diary, False), (to, False), (track, False), (triggers, False), (., False), (Follow, True), (up, False), (with, False), (results, False), (to, False), (determine, False), (appropriate, False), (treatment, False), (plan, False), (., False), (Encourage, True), (continued, False), (communication, False), (with, False), (care, False), (team, False), (for, False), (comprehensive, False), (care, False), (., False)]

# %%
transcript_entities = [ent.text for ent in transcript.ents]
transcript_entities
# Out:
# []

# %%
# Uninstall both
# !pip uninstall numpy spacy -y

# Reinstall with compatible versions
# !pip install numpy==1.24.3
# !pip install spacy==3.7.2

# Now download the model
! python -m spacy download en_core_web_sm

# %%
example
# Out:
# {'patient_convo': "\n\nPhysician: Good morning, Mr. Diaz. How are you feeling today?\n\nPatient: Hi, Dr. Burns. I've been feeling pretty lousy lately. I've had this constant heartburn that doesn't seem to go away, even when I take my medication. And sometimes, I get this sharp pain in my stomach that makes me feel like I'm going to throw up.\n\nPhysician: I see. Have you noticed any other symptoms? Maybe some bloating or abdominal discomfort?\n\nPatient: Yeah, I do get bloated a lot, and sometimes I have this feeling of fullness that lasts for hours. And the abdominal pain can be pretty intense. It's like someone is stabbing me with a knife.\n\nPhysician: I understand. Have you had any changes in your bowel movements? Maybe some diarrhea or constipation?\n\nPatient: Well, I have had some diarrhea lately, but it's not always there. And sometimes, I feel like I can't go to the bathroom even when I need to. It's like my body is just not responding.\n\nPhysician: Okay, that's helpful. Have you noticed any other symptoms? Maybe some nausea or vomiting?\n\nPatient: Yes, I do get nauseous sometimes, especially when I eat certain foods. And I have vomited a few times, but it's not constant.\n\nPhysician: I see. Have you had any recent weight changes or loss of appetite?\n\nPatient: Well, I have lost a little bit of weight recently, but I think that's because I just don't feel like eating much. And sometimes, I get